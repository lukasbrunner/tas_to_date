# %% [markdown]
# # Interactive example plot

# %%
from core.core_functions import load_plot_single
from core.utilities import regions

# %%
# possible regions
print('\n'.join(regions))
# Out:
# global
# global-land
# europe-land
# europe
# wce-land
# austria

# %%
ds, _ = load_plot_single(
    region='austria',
    year=2021,
)
# Out:
# -3.64447021484375
# 6.137536203044734
